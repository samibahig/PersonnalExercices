# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/PythonExercice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number_list = [1, 2, 3]

# %%
str_list = ['one', 'two', 'three']

# %%
result = zip()

# %%
result_list = list(result)

# %%
print(result_list)
# Out:
# []

# %%
result = zip(number_list, str_list)

# %%
result_set = set(result)

# %%
print(result_set)
# Out:
# {(3, 'three'), (1, 'one'), (2, 'two')}

# %%
result_set = set(result)

# %%
print(result_set)
# Out:
# set()

# %%
coordinate = ['x', 'y', 'z']

# %%
value = [3, 4, 5]

# %%
result = zip(coordinate, value)

# %%
result_list = list(result)

# %%
print(result_list)
# Out:
# [('x', 3), ('y', 4), ('z', 5)]
