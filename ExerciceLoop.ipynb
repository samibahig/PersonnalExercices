# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/ExerciceLoop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
items = ['un', 'pomme', 'noprint', 34, 3.1416, [], 'stop', 54321, -12]

# %%
for item in items:
    if item == 'stop':
        break
    if item == 'noprint':
        continue
    print(item)
# Out:
# un
# pomme
# 34
# 3.1416
# []
