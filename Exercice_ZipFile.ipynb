# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/Exercice_ZipFile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from zipfile import *

import zipfile
         
###jungle_zip = zipfile.ZipFile('C:\\Stories\\Fantasy\\jungle.zip', 'w')
#Homework-1.py.write('/content/Homework-1.py', compress_type=zipfile.ZIP_DEFLATED)



path = '/content/Homework-1.py'

with open("Homework-1.zip", 'w') as outfile:
    for fname in os.listdir(path):
        if not fname.endswith('.py'):
            continue
        outfile.write(os.path.join(path, fname))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-11-f39ff99ff3f4> in <module>()
#      12
#      13 with open("Homework-1.zip", 'w') as outfile:
# ---> 14     for fname in os.listdir(path):
#      15         if not fname.endswith('.py'):
#      16             continue
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/Homework-1.py'
