# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/Exercice_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(5, 20))
ax1 = fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)

# %%
ax1.hist(norm_reviews['Fandango_Ratingvalue'], bins=20, range=(0,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-42a69a8eaf04> in <module>()
# ----> 1 ax1.hist(norm_reviews['Fandango_Ratingvalue'], bins=20, range=(0,5))
#
# NameError: name 'norm_reviews' is not defined

# %%
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot(norm_reviews['RT_user_norm'])
ax.set_xticklabels(['Rotten Tomatoes'])
ax.set_ylim(0,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bf128c7d5bbf> in <module>()
#       1 fig, ax = plt.subplots()
# ----> 2 ax.boxplot(norm_reviews['RT_user_norm'])
#       3 ax.set_xticklabels(['Rotten Tomatoes'])
#       4 ax.set_ylim(0,5)
#       5 plt.show()
#
# NameError: name 'norm_reviews' is not defined

# %%
num_cols = ['RT_user_norm', 'Metacritic_user_nom', ...]
ax.boxplot(norm_reviews[num_cols].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c5ca53fe876f> in <module>()
#       1 num_cols = ['RT_user_norm', 'Metacritic_user_nom', ...]
# ----> 2 ax.boxplot(norm_reviews[num_cols].values)
#
# NameError: name 'norm_reviews' is not defined

# %%
num_cols = ['RT_user_norm', 'metacritic_user_nom', 'Fandango_Ratinfvalue', 'IMDB_norm']
fig. ax = plt.subplots()
ax.boxplot(norm_reviews[num_cols].values)
ax.set_xticklabels(num_cols, rotation=90)
ax.set_ylim(0,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-169e8dc62803> in <module>()
#       1 num_cols = ['RT_user_norm', 'metacritic_user_nom', 'Fandango_Ratinfvalue', 'IMDB_norm']
#       2 fig. ax = plt.subplots()
# ----> 3 ax.boxplot(norm_reviews[num_cols].values)
#       4 ax.set_xticklabels(num_cols, rotation=90)
#       5 ax.set_ylim(0,5)
#
# NameError: name 'norm_reviews' is not defined

# %%
import numpy as np
test = np.genfromtxt('data.csv', delimiter=',')

# %%
import numpy as np
test = np.genfromtxt('data')

# %%
world_alcohol = np.genfromtxt('world_')

# %%
world_alcohol = np.genfromtxt('world_alcohol.csv', delimiter=',')
world_alcohol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1ebb0d492ff0> in <module>()
# ----> 1 world_alcohol = np.genfromtxt('world_alcohol.csv', delimiter=',')
#       2 world_alcohol
#
# NameError: name 'np' is not defined

# %%
vector = np.array([5, 10, 15, 20])

# %%
vector = np.array([5, 10, 15, 20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0f3c5404a722> in <module>()
# ----> 1 vector = np.array([5, 10, 15, 20])
#
# NameError: name 'np' is not defined

# %%
vector[0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ab095379674a> in <module>()
# ----> 1 vector[0:3]
#
# NameError: name 'vector' is not defined

# %%
matrix = np.array([[5, 10, 15]], [20, 25, 30], [35, 40, 45]])
# Out:
#   File "<ipython-input-14-8dc2a3c01948>", line 1
#     matrix = np.array([[5, 10, 15]], [20, 25, 30], [35, 40, 45]])
#                                                                ^
# SyntaxError: invalid syntax

# %%
matrix[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-edb0c946a5d8> in <module>()
# ----> 1 matrix[:, 1]
#
# NameError: name 'matrix' is not defined

# %%
countries = world_alcohol[:,2]
print(countries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-21a81d9cee0a> in <module>()
# ----> 1 countries = world_alcohol[:,2]
#       2 print(countries)
#
# NameError: name 'world_alcohol' is not defined

# %%
matrix[:, 0:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fc3c3b712977> in <module>()
# ----> 1 matrix[:, 0:2]
#
# NameError: name 'matrix' is not defined

# %%
matrix[:, 0:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fc3c3b712977> in <module>()
# ----> 1 matrix[:, 0:2]
#
# NameError: name 'matrix' is not defined
