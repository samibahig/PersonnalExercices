# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/Copy_of_PytorchExercice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch 
t = torch.tensor([[1., -1.], [1., -1.]])
t
# Out:
# tensor([[ 1., -1.],
#         [ 1., -1.]])

# %%
t.dtype
# Out:
# torch.float32

# %%
t.shape
# Out:
# torch.Size([2, 2])
