# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/ExercicesPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Charger les modules selon la convention
import pandas as pd
import numpy as np

# Voici un dictionnaire sur le nombre d'automobiles per capita
auto_per_cap = {'États Unis': 809,'Austr.': 731,'Japon': 588,'Inde': 18,'Russie': 200,'Maroc': 70,'Egypte': 45}

# 1. Imprimer
print(auto_per_cap)

# 2. Créer une Series à partir du dictionnaire
pd_auto_per_cap = pd.Series(auto_per_cap)
pd_auto_per_cap

# Voici une liste de booléens
conduite_à_droite = [True,False,False,False,True,True,False]

# 3. Imprimer
print(conduite_à_droite)

# 4. Créer une Series à partir de la liste
pd_conduite_à_droite = pd.Series(conduite_à_droite)
pd_conduite_à_droite

# 5. Imprimer chacune des deux Series
print(pd_auto_per_cap, pd_conduite_à_droite)
# Out:
# {'États Unis': 809, 'Austr.': 731, 'Japon': 588, 'Inde': 18, 'Russie': 200, 'Maroc': 70, 'Egypte': 45}
# [True, False, False, False, True, True, False]
# États Unis    809
# Austr.        731
# Japon         588
# Inde           18
# Russie        200
# Maroc          70
# Egypte         45
# dtype: int64 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
# 6. Imprimer le type de chaque Series
___(___), ___(___)

# 7. Imprimer l'index de chaque Series
pd_auto_per_cap.___, pd_conduite_à_droite.___

# 8. Imprimer les éléments de chaque Series
pd_auto_per_cap.___, pd_conduite_à_droite.___

# 9. Remplacer avec les noms dans l'index de pd_auto_per_cap par:
# 'États-Unis', 'Australie', 'Égypte'
pd_auto_per_cap.___ = ['___','___','Japon','Inde','Russie','Maroc','___']
pd_auto_per_cap

# 10. Assigner 590 au 'Japon' et 20 à 'Inde' dans pd_auto_per_cap
pd_auto_per_cap[___, ___] = [___, ___]
pd_auto_per_cap

# 11. L'Égypte conduit à droite;
# changer le dernier élément de pd_conduite_à_droite
pd_conduite_à_droite[___] = True
pd_conduite_à_droite

# 12. Imprimer chacune des deux Series à nouveau
___, ___

# 13. Multiplier la Series pd_auto_per_cap par 1000
pd_auto_per_cap ___ ___

# 14. Créer la Series et...
pd_double = pd.Series([2,1,1,1,2,2,2])
# ...multiplier la Series pd_conduite_à_droite par
# la Series pd_double
pd_conduite_à_droite ___ ___

# Note: un booléen True vaut 1 et False vaut 0

# 15. Multiplier la Series pd_conduite_à_droite par 2
pd_conduite_à_droite ___ ___

# 16. Extraire le premier élément de pd_auto_per_cap avec l'index numérique
# ou l'index
pd_auto_per_cap[___]

# 17. Extraire le dernier booléen de pd_conduite_à_droite avec l'index numérique
# ou l'index
pd_conduite_à_droite[___]

# 18. Dans pd_auto_per_cap,
# identifier par booléens les éléments inférieurs à 100
# avec une condition
pd_auto_per_cap ___ ___

# 19. Dans pd_auto_per_cap,
# extraire les éléments supérieurs à 100
# avec une condition
pd_auto_per_cap[___ ___ ___]

# 20. Dans pd_conduite_à_droite,
# extraire les éléments True avec une condition
pd_conduite_à_droite[___ == ___]

# 21. Convertir le ndarray en Series et l'imprimer
nd_array = np.array([1,2])
pd_array = pd.___(___)
pd_array

# 22. Convertir la Series auto_per_cap en ndarray et l'imprimer
np_conduite_à_droite = np.___(pd_conduite_à_droite)
np_conduite_à_droite

# 23. Est-ce que la valeur 45 fait partie de pd_auto_per_cap?
# Indice: il s'agit d'un opérateur vu dans la section sur Numpy
45 ___ pd_auto_per_cap

# Note: passer d'un ndarray à une Series et vice-versa
# donne accès aux fonctions et méthodes de chacun des modules
# Pandas n'hérite de toutes les fonctions de Numpy telles que sort, argsort, reshape, etc.
# Pandas possède, ou pas, ses propres fonctions pour ces opérations ou possède d'autres fonctions...
# Rien n'empêche de convertir des objets en objets Numpy pour calculer avec des fonctions Numpy

# %%
# Voici un dictionnaire sur le nombre d'automobiles per capita
auto_per_cap = {'Ã‰tats Unis': 809,'Austr.': 731,'Japon': 588,'Inde': 18,'Russie': 200,'Maroc': 70,'Egypte': 45}

# 1. Imprimer
print(auto_per_cap)

# 2. CrÃ©er une Series Ã  partir du dictionnaire
pd_auto_per_cap = pd.Series(auto_per_cap)
pd_auto_per_cap

# Voici une liste de boolÃ©ens
conduite_Ã _droite = [True,False,False,False,True,True,False]

# 3. Imprimer
print(conduite_Ã _droite)

# 4. CrÃ©er une Series Ã  partir de la liste
pd_conduite_Ã _droite = pd.Series(conduite_Ã _droite)
pd_conduite_Ã _droite

# 5. Imprimer chacune des deux Series
print(pd_auto_per_cap, pd_conduite_Ã _droite)
# Out:
#   File "<ipython-input-6-dbe4737a5667>", line 12
#     conduite_Ã _droite = [True,False,False,False,True,True,False]
#                      ^
# SyntaxError: invalid character in identifier

# %%
# 6. Imprimer le type de chaque Series
___(___), ___(___)

# 7. Imprimer l'index de chaque Series
pd_auto_per_cap.___, pd_conduite_Ã _droite.___

# 8. Imprimer les Ã©lÃ©ments de chaque Series
pd_auto_per_cap.___, pd_conduite_Ã _droite.___

# 9. Remplacer avec les noms dans l'index de pd_auto_per_cap par:
# 'Ã‰tats-Unis', 'Australie', 'Ã‰gypte'
pd_auto_per_cap.___ = ['___','___','Japon','Inde','Russie','Maroc','___']
pd_auto_per_cap

# 10. Assigner 590 au 'Japon' et 20 Ã  'Inde' dans pd_auto_per_cap
pd_auto_per_cap[___, ___] = [___, ___]
pd_auto_per_cap

# 11. L'Ã‰gypte conduit Ã  droite;
# changer le dernier Ã©lÃ©ment de pd_conduite_Ã _droite
pd_conduite_Ã _droite[___] = True
pd_conduite_Ã _droite

# 12. Imprimer chacune des deux Series Ã  nouveau
___, ___

# 13. Multiplier la Series pd_auto_per_cap par 1000
pd_auto_per_cap ___ ___

# 14. CrÃ©er la Series et...
pd_double = pd.Series([2,1,1,1,2,2,2])
# ...multiplier la Series pd_conduite_Ã _droite par
# la Series pd_double
pd_conduite_Ã _droite ___ ___

# Note: un boolÃ©en True vaut 1 et False vaut 0

# 15. Multiplier la Series pd_conduite_Ã _droite par 2
pd_conduite_Ã _droite ___ ___

# 16. Extraire le premier Ã©lÃ©ment de pd_auto_per_cap avec l'index numÃ©rique
# ou l'index
pd_auto_per_cap[___]

# 17. Extraire le dernier boolÃ©en de pd_conduite_Ã _droite avec l'index numÃ©rique
# ou l'index
pd_conduite_Ã _droite[___]

# 18. Dans pd_auto_per_cap,
# identifier par boolÃ©ens les Ã©lÃ©ments infÃ©rieurs Ã  100
# avec une condition
pd_auto_per_cap ___ ___

# 19. Dans pd_auto_per_cap,
# extraire les Ã©lÃ©ments supÃ©rieurs Ã  100
# avec une condition
pd_auto_per_cap[___ ___ ___]

# 20. Dans pd_conduite_Ã _droite,
# extraire les Ã©lÃ©ments True avec une condition
pd_conduite_Ã _droite[___ == ___]

# 21. Convertir le ndarray en Series et l'imprimer
nd_array = np.array([1,2])
pd_array = pd.___(___)
pd_array

# 22. Convertir la Series auto_per_cap en ndarray et l'imprimer
np_conduite_Ã _droite = np.___(pd_conduite_Ã _droite)
np_conduite_Ã _droite

# 23. Est-ce que la valeur 45 fait partie de pd_auto_per_cap?
# Indice: il s'agit d'un opÃ©rateur vu dans la section sur Numpy
45 ___ pd_auto_per_cap

# Note: passer d'un ndarray Ã  une Series et vice-versa
# donne accÃ¨s aux fonctions et mÃ©thodes de chacun des modules
# Pandas n'hÃ©rite de toutes les fonctions de Numpy telles que sort, argsort, reshape, etc.
# Pandas possÃ¨de, ou pas, ses propres fonctions pour ces opÃ©rations ou possÃ¨de d'autres fonctions...
# Rien n'empÃªche de convertir des objets en objets Numpy pour calculer avec des fonctions Numpy
