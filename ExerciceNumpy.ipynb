# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/ExerciceNumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_of_list = [['Paris', 75], ['Lyon', 69]]

# %%
list = [1, 'film', 3]

# %%
list.append('series')
print(list)
# Out:
# [1, 'film', 3, 'series']

# %%
import numpy as np

# %%
vector = np.array([3, 4, 17, 65])

# %%
matrix = np.array([[2, 5, 15], [20, 50, 30], [34, 99, 45]])

# %%
print(matrix)
# Out:
# [[ 2  5 15]
#  [20 50 30]
#  [34 99 45]]

# %%
import numpy as np
vector = np.array([10, 20, 30])
matrix = np.array([[5, 10, 15], [20, 25, 30], [35, 40, 45]])
print(vector)
# Out:
# [10 20 30]

# %%
vector = np.array([1, 2, 3, 4])
print(vector.shape)
# Out:
# (4,)

# %%
matrix = np.array([[5, 10, 15], [20, 25, 30]])
print(matrix.shape)
# Out:
# (2, 3)

# %%
vector_shape = vector.shape
matrix_shape = matrix.shape
print(vector_shape)
print(matrix_shape)
# Out:
# (4,)
# (2, 3)

# %%
import numpy as np
test = np.genfromtxt('data.csv', delimiter=',')

# %%
import pandas as pd
reviews = pd.read_csv('fandango_scores.csv')
cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue']

norm_reviews = reviews[cols]
print(norm_reviews[:5])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2ce2e17550c2> in <module>()
#       1 import pandas as pd
# ----> 2 reviews = pd.read_csv('fandango_scores.csv')
#       3 cols = ['FILM', 'RT_user_norm', 'Metacritic_user_nom', 'IMDB_norm', 'Fandango_Ratingvalue']
#       4
#       5 norm_reviews = reviews[cols]
#
# ...

# %%
sorted_freq_counts = freq_counts.sort_index()
sorted_freq_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a27a0df8340c> in <module>()
# ----> 1 sorted_freq_counts = freq_counts.sort_index()
#       2 sorted_freq_counts
#
# NameError: name 'freq_counts' is not defined

# %%
imdb_distribution = norm_reviews['IMDB_norm'].value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e32ed3eb180e> in <module>()
# ----> 1 imdb_distribution = norm_reviews['IMDB_norm'].value
#
# NameError: name 'norm_reviews' is not defined

# %%
imdb_distribution = imdb_distribution.sort_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-59e034fab96a> in <module>()
# ----> 1 imdb_distribution = imdb_distribution.sort_index()
#
# NameError: name 'imdb_distribution' is not defined

# %%
import matplotlib.pyplot a splt
fig, ax = plt.subplots()
ax.hist(norm_reviews['Fandango_Ratingvalue'], range=(0,5))
# Out:
#   File "<ipython-input-7-e208efda2365>", line 1
#     import matplotlib.pyplot a splt
#                              ^
# SyntaxError: invalid syntax

# %%
ax.hist(df[col], range=(0,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e4c6576dafc7> in <module>()
# ----> 1 ax.hist(df[col], range=(0,5))
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.pyplot as plt 
fig = plt.figure(figsize=(5,20))
