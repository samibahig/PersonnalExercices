# %% [markdown]
# <a href="https://colab.research.google.com/github/samibahig/PersonnalExercices/blob/main/Exercice_Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/raw_data.csv', parse_dates=['date'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-617f72d80a32> in <module>()
# ----> 1 df = pd.read_csv('/content/raw_data.csv', parse_dates=['date'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
df
# Out:
#       iso_code     location       date  ...  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0          AFG  Afghanistan 2019-12-31  ...        #NUM!    17.477233  7.497754494
# 1          AFG  Afghanistan 2020-01-01  ...        #NUM!    17.477233  7.497754494
# 2          AFG  Afghanistan 2020-01-02  ...        #NUM!    17.477233  7.497754494
# 3          AFG  Afghanistan 2020-01-03  ...        #NUM!    17.477233  7.497754494
# 4          AFG  Afghanistan 2020-01-04  ...        #NUM!    17.477233  7.497754494
# ...        ...          ...        ...  ...          ...          ...          ...
# 50413      ZWE     Zimbabwe 2020-10-15  ...   4.34185547    16.514381  7.549490737
# 50414      ZWE     Zimbabwe 2020-10-16  ...   4.34185547    16.514381  7.549490737
# 50415      ZWE     Zimbabwe 2020-10-17  ...   4.34185547    16.514381  7.549490737
# 50416      ZWE     Zimbabwe 2020-10-18  ...   4.34185547    16.514381  7.549490737
# ...

# %%
df.shape
# Out:
# (50418, 14)

# %%
df.head(15)
# Out:
#    iso_code     location       date  ...  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0       AFG  Afghanistan 2019-12-31  ...        #NUM!    17.477233  7.497754494
# 1       AFG  Afghanistan 2020-01-01  ...        #NUM!    17.477233  7.497754494
# 2       AFG  Afghanistan 2020-01-02  ...        #NUM!    17.477233  7.497754494
# 3       AFG  Afghanistan 2020-01-03  ...        #NUM!    17.477233  7.497754494
# 4       AFG  Afghanistan 2020-01-04  ...        #NUM!    17.477233  7.497754494
# 5       AFG  Afghanistan 2020-01-05  ...        #NUM!    17.477233  7.497754494
# 6       AFG  Afghanistan 2020-01-06  ...        #NUM!    17.477233  7.497754494
# 7       AFG  Afghanistan 2020-01-07  ...        #NUM!    17.477233  7.497754494
# 8       AFG  Afghanistan 2020-01-08  ...        #NUM!    17.477233  7.497754494
# 9       AFG  Afghanistan 2020-01-09  ...        #NUM!    17.477233  7.497754494
# 10      AFG  Afghanistan 2020-01-10  ...        #NUM!    17.477233  7.497754494
# ...

# %%
import pandas as pd

# %%
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'], 'Height': [5.1, 6.2, 5.1, 5.2], 'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}

# %%
df['day of the week'] = df['date'].dt.dayofweek

# %%
df1 = pd.DataFrame({'id': [1, 2, 3],'name': ['Alice', 'Bob', 'Carl']})

# %%
df2 = pd.DataFrame({'id': [1, 2, 3],'name': ['David', 'Elsa', 'Carl']})

# %%
merged = pd.merge(df1, df2)

# %%
print(merged)
# Out:
#    id  name
# 0   3  Carl

# %%
store_a_b_outer = df.merge(store_a, store_b, how= 'outer')
print(store_a_b_outer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d70f2858d507> in <module>()
# ----> 1 store_a_b_outer = df.merge(store_a, store_b, how= 'outer')
#       2 print(store_a_b_outer)
#
# NameError: name 'df' is not defined

# %%
df1 = pd.DataFrame({'id': [1, 2, 3], 'name': ['Alice', 'Bob', 'Carl']})

# %%
df2 = pd.DataFrame({'id': [1, 2, 3],'name': ['David', 'Elsa', 'Carl']})

# %%
df1
# Out:
#    id   name
# 0   1  Alice
# 1   2    Bob
# 2   3   Carl

# %%
df2
# Out:
#    id   name
# 0   1  David
# 1   2   Elsa
# 2   3   Carl

# %%
merged = pd.merge(df1, df2)

# %%
print(merged)
# Out:
#    id  name
# 0   3  Carl

# %%
df1.merge(df2)
# Out:
#    id  name
# 0   3  Carl

# %%
df1.merge(df2, on='id')
# Out:
#    id name_x name_y
# 0   1  Alice  David
# 1   2    Bob   Elsa
# 2   3   Carl   Carl

# %%
frames = [df1, df2]

# %%
frames
# Out:
# [   id   name
#  0   1  Alice
#  1   2    Bob
#  2   3   Carl,    id   name
#  0   1  David
#  1   2   Elsa
#  2   3   Carl]

# %%
pd.concat(frames, axis=1, join="inner', ignore_index=False, keys=[0,1], index=[1], levels=None)
# Out:
#   File "<ipython-input-59-183e5bf6e146>", line 1
#     pd.concat(frames, axis=1, join="inner', ignore_index=False, keys=[0,1], index=[1], levels=None)
#                                                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
df1.iloc[0:2]
# Out:
#    id   name
# 0   1  Alice
# 1   2    Bob

# %%
df1.isnull()
# Out:
#       id   name
# 0  False  False
# 1  False  False
# 2  False  False

# %%
df1.notnull()
# Out:
#      id  name
# 0  True  True
# 1  True  True
# 2  True  True
